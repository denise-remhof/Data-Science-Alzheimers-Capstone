# %% [markdown]
# # Exploring relationships between Diabetes & Alzheimer's

# %% [markdown]
# ## Abstract:
#
#
# ### Background
#
# An estimated 5.4 million people in the United States suffer from Alzheimer's disease. It's the 6th-leading cause of death in the US, higher than breast & prostate cancer combined. One interesting insight is the fact that Alzheimer's may be related to high levels of blood glucose, as is seen in diabetes. County-level diabetes rates can be predicted well using a Random Forest model, I wanted to see if Alzheimer's rates can also be predicted--and what factors the two diseases might have in common.
#
# ### Methods
#
# Because health is affected by a wide range of variables, I sought out all publicly available county data on health, food access, socioeconomics, demographics, and employment. My research & predictions are centered around county-level data.
#
# ### Models
#
# I used Random Forest Regression models to predict:
#
# * Age-adjusted Alzheimer's mortality
# * Age-adjusted Diabetes mortality
# * Adult Diabetes rates
#
# I also used Lasso and Decision Tree regression to investigate relationships between variables.
#
# ### Findings
#
# The incidence of Adult Diabetes in a given county is highly predictable, while age-adjusted Diabetes & Alzheimer's mortality rates are less so.
#
# While Adult Diabetes and Diabetes mortality share several variables, Alzheimer's mortality predictors differ slightly.

# %%
from IPython.display import Image
Image("/Users/deniseremhof/Capstone/Images/alz_mort_reg.png")

# %%
Image("/Users/deniseremhof/Desktop/Capstone/Images/dia_death_reg.png")

# %%
Image("/Users/deniseremhof/Downloads/adult_dia_reg.png")

# %% [markdown]
# ### Important variables
#
# The features in the Diabetes/Diabetes mortality rate models show clear similarities--it's easy to deduce feature relationships even with the black box nature of the models. Features that correlate to high Diabetes mortality rate and Adult Diabetes include:
#
# * Poverty/Low Income
# * Food Insecurity/Access
# * Low education
# * Usage of government food aid such as SNAP
# * High overall mortality rate
#
# Because the collinearity of Alzheimer's mortality-related features is tough to tease out on feature importance alone, I used Lasso and a single Decision Tree to dig into feature relationships for Alzheimer's mortality rate. I found that
# the following relate positively to  Alzheimer's mortality rates:
#
# * Per capita and household income income (especially when in larger metro areas)
# * Obesity (especially when in larger metro areas)
# * Education levels (some college +)
# * Overall age-adjusted mortality rate
# * County classification as a retirement destination. This measure is particularly interesting because the Alzheimer's mortality rates have been age-adjusted. This means that there's something important about retirement communities OTHER than advanced age of county residence.
# * High fast food consumption
# * Low unemployment
# * High population % who are 65+ (this is especially interesting because the Alzheimer's mortality rate is age-adjusted, meaning there's something intrinsic to these counties OTHER than having a high percentage of people who are likely to die from Alzheimer's.
# * Household food insecurity (lack of access to grocery stores, where convenience stores might instead be fulfilling a county's nutritional needs). This is in line with what we'd find in a larger, high-density metro area.
# * High % of veterans. Veterans tend to be older (the average age is 58), so this is in line with our findings about older populations.

# %% [markdown]
# ### Conclusions & Further Research
#
# The incidence of Adult Diabetes in a given county is highly predictable, while age-adjusted Diabetes & Alzheimer's mortality rates are less so.
#
# While Adult Diabetes and Diabetes mortality share several variables, Alzheimer's mortality predictors differ greatly from them. Any medical relationship between Alzheimer's and Diabetes doesn't manifest itself strongly in the given predictors.
#
# I hypothesize that as higher-income, higher-education people live longer and move to retirement communities, the likelihood of contracting Alzheimer's increases.
#
# One aspect I'm curious about is the paradoxical nature of both lack of food access/high fast food consumption, combined with high income. These factors may not manifest themselves in the same counties; it's possible that these two groups exist in different regions. The map below suggests that Alzheimer's mortality rates are particularly high in the southern states--where you'd typically find "food deserts"--but also in wealthier, denser areas on the coasts.
#
# It's possible that the publicly available county-level predictors are insufficient for the purpose of Alzheimer's incidence. Future Alzheimer's research should consider other factors not included in this report. For example, county-level data on blood glucose levels or sugar consumption might provide better links between Diabetes & Alzheimer's.
#
# It's a shame that county-level Alzheimer's rates aren't available, as they'd likely provide more clarity than Alzheimer's rates alone. These Alzheimer's county rates have been imputed by other studies, but the data is unavailable to the public.

# %% [markdown]
# ### Feature Importances

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
# %matplotlib inline

alz = pd.read_csv('/Users/deniseremhof/Desktop/alz_oct_11.csv')
alz = alz.drop('Unnamed: 0', axis=1)

# %%
from sklearn.ensemble import RandomForestRegressor
## Define y
y = alz['death_rate_alz']

## Define X
columns_ = alz.columns.tolist()
exclude_cols = ['death_rate_alz','county_name','FIPS','State']
X = alz[[i for i in columns_ if i not in exclude_cols]]

## Print shapes of y and X
print y.shape, X.shape
# Out:
# (2701,) (2701, 139)

# %% [markdown]
# ### Baselines/EDA

# %% [markdown]
# Data include:
#
# #### Socioeconomic Factors
#     a) Access/availability of grocery stores, convenience stores, superstores
#     b) Goverment food assistance such as SNAP/WIC
#     c) Education levels
#     d) Unemployment
#     e) Poverty/child poverty
#     f) Income
#
#
# #### Health factors
#     a) Age-adjusted overall mortality rate
#     b) Age-adjusted Alzheimer's mortality rate
#     c) Adult & childhood obesity rates
#     d) Adult diabetes rates
#     e) Inactivity rates
#     f) Obesity Rates
#
# #### Demographics
#     a) Ethnic background
#     b) Veterans
#     c) English-speaking households
#
# #### County Classifications
#     a) Metro vs. NonMetro
#     b) Economic dependencies (farming, mining, government, etc.)
#     c) Rural/urban continuum code
#     d) State

# %% [markdown]
# #### d3  Map: Alzheimer's Mortality Rates by County

# %%
Image("/Users/deniseremhof/Downloads/alz_mortality.png")

# %% [markdown]
# ####  Interactions of key features

# %% [markdown]
# This heatmap shows correlations between features in this dataset. Most notably, it calls out the relationships between income, poverty level, mortality rate, and education.

# %%
food = alz[['per_capita_fast_food','grocery_per1k', 'median_hh_income', 'per_capita_income', 'snap_spend_per_store', 
            'pop_density', 'pop_12', 'retirement_destination_county','fastfood_per1k',
           'pct_employed_manufacturing','manufacturing_dependent','milk_price','child_poverty_rate','poverty_rate',
           'adult_obese_rate', 'pop_density','mortality_rate','per_capita_income', 'no_high_school', 'hs_only', 
            'some_college', 'assoc_degree',
       'college_plus']]

sns.set(style="white")

corr = food.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, ax=ax)

plt.show()

# %% [markdown]
# #### The following 2 graphs show baseline distributions for various mortality rates, as well as incidence of Adult Diabetes.

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca()
plt.style.use('ggplot')

ax = sns.boxplot(data=alz[['death_rate_alz','dia_death_rate']], ax=ax, notch=True)
ax.set_title("Age-Adjusted Alzheimer's Mortality Rates", fontsize=18)
plt.ylabel('Rate (per 100k)',fontsize=15)

plt.show()

# %%
alz.death_rate_alz.describe()
# Out:
# count    2701.000000
# mean       51.673380
# std        13.492806
# min         9.600000
# 25%        42.300000
# 50%        51.200000
# 75%        60.400000
# max       116.700000
# Name: death_rate_alz, dtype: float64

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.gca()
plt.style.use('ggplot')


ax = sns.boxplot(data=alz[['mortality_rate']], ax=ax, notch=True,color='r')
ax.set_title("Baseline Age-Adjusted Mortality Rate", fontsize=18)
plt.ylabel('Rate (per 100k)',fontsize=15)

plt.show()

# %%
fig = plt.figure(figsize=(10,8))

ax = fig.add_subplot(111)
fig.suptitle("Adult Diabetes Rates", fontsize=14, fontweight='bold')
plt.hist(X.adult_diabetes_rate,alpha=0.5, label='Diabetes', color = 'orange')
ax.set_xlabel("% of adults with Diabetes")

plt.show()

# %% [markdown]
# ### Which variables correlate with our target variables?

# %%
new_df = alz.corr()

# %%
new_df['death_rate_alz'].sort_values(ascending=False)
# Out:
# death_rate_alz                    1.000000
# per_capita_fast_food              0.217514
# retirement_destination_county     0.205488
# metro_250k_1mil                   0.167313
# college_plus                      0.160124
# GA                                0.159321
# median_hh_income                  0.147439
# metro_1mil_plus                   0.146636
# fastfood_per1k                    0.143827
# mortality_rate                    0.129525
# SC                                0.126955
# snap_spend_per_store              0.125418
# pct_employed_services             0.122292
# NC                                0.115859
# some_college                      0.103518
# pct_under18                       0.097982
# per_capita_income                 0.095208
# per_capita_full_service           0.087347
# AL                                0.077637
# TN                                0.073869
# avg_hh_size                       0.069546
# TX                                0.065470
# VA                                0.057704
# rec_facil_per1k                   0.057320
# household_foodinsec               0.053096
# OR                                0.051404
# pct_black                         0.050223
# FIPS                              0.046510
# milk_soda_price                   0.045115
# ME                                0.044607
#                                     ...
# IA                               -0.080274
# soda_tax_stores                  -0.080615
# NJ                               -0.081254
# pop_density                      -0.081770
# noncore_microadj_lessthan2500    -0.081817
# pct_hisp                         -0.082982
# snap_stores_per1k                -0.084678
# MO                               -0.086411
# no_high_school                   -0.089624
# inactivity_rate                  -0.095367
# seniors_lo_store_pct             -0.098618
# CA                               -0.104493
# low_employment_county            -0.104761
# households_lo_car_store_pct      -0.105063
# poverty_rate                     -0.109497
# per_child_poverty_county_class   -0.114082
# active_high_schoolers            -0.118684
# child_poverty_rate               -0.121328
# noncore_microadj_lessthan20k     -0.123835
# wic_stores_per1k                 -0.125400
# farming_dependent                -0.128899
# unemployment                     -0.130467
# per_poverty_county_class         -0.133268
# NY                               -0.158133
# hs_only                          -0.178449
# pop_loss_class                   -0.186333
# grocery_per1k                    -0.194677
# pct_employed_agriculture         -0.217560
# pct_over65                       -0.226676
# pct_hh_65plus_livealone          -0.258144
# Name: death_rate_alz, dtype: float64

# %%
new_df['mortality_rate'].sort_values(ascending=False)
# Out:
# mortality_rate                    1.000000
# adult_diabetes_rate               0.716438
# inactivity_rate                   0.704801
# child_poverty_rate                0.683710
# snap_per_capita                   0.678741
# poverty_rate                      0.652946
# no_high_school                    0.618644
# snap_stores_per1k                 0.594816
# adult_obese_rate                  0.521680
# dia_death_rate                    0.513483
# low_employment_county             0.508699
# unemployment                      0.495907
# households_lo_car_store_pct       0.487380
# per_child_poverty_county_class    0.481125
# household_foodinsec               0.449485
# pct_black                         0.438001
# hs_only                           0.410732
# per_poverty_county_class          0.408701
# convenience_per1k                 0.375695
# milk_soda_price                   0.346670
# low_education_county              0.342150
# child_foodinsec                   0.325897
# milk_price                        0.270568
# food_tax                          0.270140
# chips_tax_stores                  0.270140
# per_capita_fast_food              0.230156
# KY                                0.215842
# MS                                0.213231
# pct_employed_govt                 0.175005
# AL                                0.174639
#                                     ...
# farming_dependent                -0.113746
# NE                               -0.118761
# CA                               -0.126046
# active_high_schoolers            -0.130094
# SD                               -0.132181
# CO                               -0.133916
# some_college                     -0.139956
# WI                               -0.140573
# metro_1mil_plus                  -0.151516
# IA                               -0.173723
# pct_hisp                         -0.176291
# pop_12                           -0.179294
# pct_white                        -0.186783
# seniors_lo_store_pct             -0.190808
# child_lo_store_pct               -0.192373
# lo_store_pct                     -0.199737
# recreation_county                -0.204686
# pct_nonenglish_hh                -0.206917
# MN                               -0.215909
# per_capita_full_service          -0.230659
# soda_price                       -0.253993
# pct_employed_services            -0.304255
# spec_per1k                       -0.310274
# pct_asian                        -0.318937
# rec_facil_per1k                  -0.355473
# full_service_per1k               -0.366728
# assoc_degree                     -0.426172
# college_plus                     -0.590767
# median_hh_income                 -0.609294
# per_capita_income                -0.639018
# Name: mortality_rate, dtype: float64

# %%
new_df['adult_diabetes_rate'].sort_values(ascending=False)
# Out:
# adult_diabetes_rate               1.000000
# inactivity_rate                   0.734878
# mortality_rate                    0.716438
# child_poverty_rate                0.641488
# adult_obese_rate                  0.576772
# snap_stores_per1k                 0.574848
# households_lo_car_store_pct       0.564157
# snap_per_capita                   0.562827
# poverty_rate                      0.554420
# no_high_school                    0.544639
# low_employment_county             0.497207
# unemployment                      0.493359
# hs_only                           0.492080
# pct_black                         0.490799
# per_child_poverty_county_class    0.458578
# milk_soda_price                   0.404693
# household_foodinsec               0.400150
# convenience_per1k                 0.397822
# dia_death_rate                    0.383439
# per_poverty_county_class          0.376526
# milk_price                        0.307030
# pct_hh_65plus_livealone           0.299067
# food_tax                          0.281449
# chips_tax_stores                  0.281449
# low_education_county              0.262559
# pct_over65                        0.255094
# child_foodinsec                   0.251242
# MS                                0.244797
# AL                                0.224605
# pct_employed_manufacturing        0.216914
#                                     ...
# MT                               -0.104813
# NE                               -0.105992
# WI                               -0.120368
# UT                               -0.123208
# IA                               -0.138713
# pct_white                        -0.158765
# lo_store_pct                     -0.160919
# poor_air_quality                 -0.163318
# active_high_schoolers            -0.168155
# CA                               -0.174040
# fastfood_per1k                   -0.181514
# child_lo_store_pct               -0.185757
# MN                               -0.186725
# metro_1mil_plus                  -0.190238
# pop_12                           -0.194310
# some_college                     -0.203645
# spec_per1k                       -0.241473
# pct_nonenglish_hh                -0.254988
# CO                               -0.261465
# pct_hisp                         -0.269267
# per_capita_full_service          -0.285165
# soda_price                       -0.312580
# full_service_per1k               -0.324499
# pct_asian                        -0.328008
# assoc_degree                     -0.335582
# pct_employed_services            -0.342994
# rec_facil_per1k                  -0.369516
# per_capita_income                -0.569737
# median_hh_income                 -0.583999
# college_plus                     -0.598943
# Name: adult_diabetes_rate, dtype: float64

# %% [markdown]
# ### Prepare for Random Forest Regression.
#
# I selected a Random Forest model because:
#
# * I have a lot of variables, both categorical and continuous
# * I'm seeking high accuracy, and I'm sure there are relationships between variables that I wouldn't be able to come up with on my own

# %% [markdown]
# #### Train/test split, gridsearch optimal parameters, and fit the model

# %%
## Train test split 70/30
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

## Print shapes of X(s) and y(s)
print X_train.shape, y_train.shape
print X_test.shape, y_test.shape
# Out:
# (1890, 139) (1890,)
# (811, 139) (811,)

# %%
from sklearn.grid_search import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor( )

params = {'max_depth':[2,3,4,5,6,None], 
          'max_features':['sqrt','log2'],
          'min_samples_split':[2,4,8,16,32,64,128],
          'n_estimators': [500]
         }

estimator_rfr = GridSearchCV(forest, params, n_jobs=1, cv=5, verbose=2)

# %%
model = estimator_rfr.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 84 candidates, totalling 420 fits
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=2 -   1.3s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=2 -   1.3s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=2 -   1.3s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=2 -   1.3s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=2
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=2
# [Parallel(n_jobs=1)]: Done  40 tasks       | elapsed:   48.1s
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=2 -   1.3s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=2 -   1.3s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=2 -   1.3s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=2 -   1.2s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=2
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=2 -   1.1s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=3 -   1.5s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=3 -   1.5s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=3
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=3 -   1.2s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=3 -   1.2s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=3 -   1.2s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=3 -   1.2s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=3 -   1.2s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=3 -   1.2s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=3 -   1.2s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=3 -   1.2s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=3 -   1.2s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=3 -   1.2s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=3 -   1.2s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=3 -   1.4s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=3 -   1.2s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=3 -   1.2s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=3 -   1.2s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=3 -   1.2s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=3 -   1.2s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=3 -   1.2s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=3 -   1.3s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=3
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=3 -   1.2s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=4 -   1.5s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=4 -   1.5s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=4 -   1.6s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=4 -   1.6s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=4 -   1.6s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=4 -   1.6s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=4 -   1.6s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=4 -   1.6s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=4 -   1.5s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=4 -   1.5s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=4 -   1.5s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=4 -   1.5s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=4 -   1.6s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=4 -   1.6s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=4 -   1.6s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=4 -   1.6s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=4 -   1.6s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=4 -   1.5s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=4 -   1.5s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=4 -   1.5s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=4 -   1.6s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=4
# [Parallel(n_jobs=1)]: Done 161 tasks       | elapsed:  3.5min
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=4 -   1.5s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=4 -   1.5s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=4 -   1.5s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=4 -   1.5s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=4 -   1.5s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=4 -   1.5s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=4 -   1.4s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=4 -   1.4s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=4 -   1.4s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=4 -   1.4s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=4 -   1.4s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=4 -   1.6s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=4 -   1.5s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=4
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=4 -   1.5s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=4 -   1.4s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=4 -   1.4s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=4 -   1.4s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=4 -   1.4s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=4 -   1.4s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=4 -   1.4s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=4 -   1.4s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=4
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=4 -   1.3s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=5 -   1.7s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=5 -   1.5s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=5 -   1.5s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=5 -   1.5s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=5
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=5 -   1.6s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=5 -   1.5s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=5 -   1.5s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=5 -   1.5s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=5 -   1.5s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=5 -   1.3s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=5 -   1.3s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=5 -   1.3s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=5 -   1.3s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=5 -   1.3s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=5 -   1.4s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=5
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=5 -   1.3s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=6
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=6 -   1.8s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=6
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=6 -   1.8s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=6
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=6 -   1.7s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=6
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=6 -   1.8s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=6
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=6 -   1.8s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=6
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=6 -   1.8s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=6
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=6 -   1.9s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=6
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=6 -   1.8s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=6
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=6 -   1.8s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=6
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=6 -   1.8s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=6
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=6 -   1.9s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=6
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=6 -   1.8s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=6
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=6 -   1.8s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=6
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=6 -   1.8s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=6
# ...
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=6 -   1.5s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=6 -   1.5s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=6 -   1.5s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=6 -   1.5s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=6 -   1.5s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=6 -   1.5s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=6 -   1.5s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=6 -   1.6s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=6 -   1.6s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=6 -   1.5s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=6 -   1.5s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=6 -   1.5s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=6 -   1.6s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=6 -   1.6s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=6 -   1.5s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=6 -   1.5s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=6 -   1.5s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=6 -   1.5s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=6 -   1.4s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=6 -   1.4s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=6 -   1.4s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=6 -   1.4s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=6 -   1.4s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=6 -   1.4s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=6
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=6 -   1.5s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=None -   3.3s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=None -   3.2s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=None -   3.2s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=None -   3.2s
# [CV] max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=2, n_estimators=500, max_depth=None -   3.2s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=None -   2.9s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=None -   2.9s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=None -   2.9s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=None -   2.9s
# [CV] max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=4, n_estimators=500, max_depth=None -   2.9s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=None -   2.7s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=None -   2.6s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=None -   2.7s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=None -   2.6s
# [CV] max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=None
# [Parallel(n_jobs=1)]: Done 364 tasks       | elapsed:  8.9min
# [CV]  max_features=sqrt, min_samples_split=8, n_estimators=500, max_depth=None -   2.7s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=None -   2.4s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=None -   2.5s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=None -   2.4s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=None -   2.4s
# [CV] max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=16, n_estimators=500, max_depth=None -   2.5s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=None -   2.3s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=None -   2.2s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=None -   2.2s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=None -   2.2s
# [CV] max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=32, n_estimators=500, max_depth=None -   2.2s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=None -   1.9s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=None -   1.9s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=None -   2.0s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=None -   2.0s
# [CV] max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=64, n_estimators=500, max_depth=None -   2.0s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=None -   1.7s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=None -   1.7s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=None -   1.7s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=None -   1.8s
# [CV] max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=None
# [CV]  max_features=sqrt, min_samples_split=128, n_estimators=500, max_depth=None -   1.8s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=None -   2.4s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=None -   2.4s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=None -   2.4s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=None -   2.4s
# [CV] max_features=log2, min_samples_split=2, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=2, n_estimators=500, max_depth=None -   2.4s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=None -   2.2s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=None -   2.2s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=None -   2.2s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=None -   2.2s
# [CV] max_features=log2, min_samples_split=4, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=4, n_estimators=500, max_depth=None -   2.2s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=None -   2.1s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=None -   2.1s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=None -   2.1s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=None -   2.1s
# [CV] max_features=log2, min_samples_split=8, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=8, n_estimators=500, max_depth=None -   2.1s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=None -   1.9s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=None -   1.9s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=None -   2.0s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=None -   2.0s
# [CV] max_features=log2, min_samples_split=16, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=16, n_estimators=500, max_depth=None -   2.0s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=None -   1.9s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=None -   1.8s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=None -   1.9s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=None -   1.9s
# [CV] max_features=log2, min_samples_split=32, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=32, n_estimators=500, max_depth=None -   1.9s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=None -   1.7s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=None -   1.7s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=None -   1.7s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=None -   1.7s
# [CV] max_features=log2, min_samples_split=64, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=64, n_estimators=500, max_depth=None -   1.7s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=None -   1.5s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=None -   1.5s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=None -   1.5s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=None -   1.5s
# [CV] max_features=log2, min_samples_split=128, n_estimators=500, max_depth=None
# [CV]  max_features=log2, min_samples_split=128, n_estimators=500, max_depth=None -   1.6s
# [Parallel(n_jobs=1)]: Done 420 out of 420 | elapsed: 10.8min finished

# %% [markdown]
# ### Best parameters, estimators, and score
#
# About this....

# %%
## Print best estimator, best parameters, and best score
rfr_best = estimator_rfr.best_estimator_
print "best estimator", rfr_best
print "\n==========\n"
print "best parameters", estimator_rfr.best_params_
print "\n==========\n"
print "best score", estimator_rfr.best_score_
# Out:
# best estimator RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=500, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)
#
# ==========
#
# best parameters {'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 500, 'max_depth': None}
#
# ==========
#
# best score 0.305892224549

# %% [markdown]
# ### Mean-squared error and R^2

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_train_pred = estimator_rfr.predict(X_train)
y_test_pred = estimator_rfr.predict(X_test)

print('MSE train: %.2f, test: %.2f' % (
        mean_squared_error(y_train, y_train_pred),
        mean_squared_error(y_test, y_test_pred)))
print('R^2 train: %.2f, test: %.2f' % (
        r2_score(y_train, y_train_pred),
        r2_score(y_test, y_test_pred)))
# Out:
# MSE train: 17.07, test: 115.76
# R^2 train: 0.91, test: 0.35

# %%
cols = X.columns

r2 = r2_score(y_test, y_test_pred)
mse = mean_squared_error(y_test, y_test_pred)

# %%
plt.figure(figsize = (10,10))
plt.scatter(y, rfr_best.predict(X[cols]))
import matplotlib.patches as mpatches
plt.plot(legend="r^2=" + str(r2))
plt.legend(loc="lower right")
red_patch = mpatches.Patch(color='red', label="r^2=" + str(r2))
plt.legend(handles=[red_patch])
plt.title("Alzheimer's Mortality, Random Forest")
plt.xlabel("actual")
plt.ylabel("predicted")
plt.show()

# %%
plt.figure(figsize = (11,11))
plt.scatter(y, rfr_best.predict(X[cols]))
plt.plot(label="r^2=" + str(r2), c="r")
plt.legend(loc="lower right")
plt.title("Alzheimer's Mortality, Random Forest")
plt.xlabel("actual")
plt.ylabel("predicted")
plt.show()

# %% [markdown]
# ### Plot Residuals to look for bias

# %%
yhat = rfr_best.predict(X)

resid = y - yhat

# %%
sns.distplot(resid, bins=40, hist=True, kde=False)
plt.show()

# %% [markdown]
# #### Diabetes & Diabetes Mortality Rate
#
# Random Forest code, models & plots for diabetes rates can be found here:
# https://github.com/nikkikat3/DSI-SF-2-nikkikat3/commit/e004a2432eaa333fd3c651f4dff75981298bb7e3

# %%
Image("/Users/deniseremhof/Downloads/adult_dia_reg.png")

# %%
Image("/Users/deniseremhof/Downloads/dia_death_reg.png")

# %% [markdown]
# #### What can be said about these models?
#
# The Adult Diabetes model accounts for the most variance, with an R^2 of .80
#
# The Alzheimer's and Diabetes mortality rate models perform similarly to one another at .35 and .37, respectively.

# %% [markdown]
# ### Random Forest Feature Importances

# %%
## Print Feature importances
feature_importance = pd.DataFrame({ 'feature':X.columns, 
                                   'importance':rfr_best.feature_importances_
                                  })

feature_importance.sort_values('importance', ascending=False, inplace=True)
feature_importance.reset_index(inplace=True)

# %%
feature_importance.feature.dtypes
feature_importance['feature'] = map(lambda x: str(x), feature_importance.feature.values)
feature_importance['importance'] = map(lambda x: float(x), feature_importance.importance.values)

# %%
feature_importance[feature_importance['importance'] > 0]
# Out:
#      index                     feature  importance
# 0       47                 pop_density    0.035261
# 1       52    pct_employed_agriculture    0.031605
# 2        1                      pop_12    0.028530
# 3       69              mortality_rate    0.025640
# 4       50     pct_hh_65plus_livealone    0.023192
# 5       27               grocery_per1k    0.021867
# 6       25        per_capita_fast_food    0.021160
# 7       39                  pct_over65    0.019790
# 8      134                     hs_only    0.019180
# 9       41            median_hh_income    0.019110
# 10      37                  pct_native    0.018937
# 11      40                 pct_under18    0.017954
# 12      35                    pct_hisp    0.017488
# 13      53  pct_employed_manufacturing    0.017161
# 14      33                   pct_white    0.017045
# 15      66                    vets_pct    0.017011
# 16       6        snap_spend_per_store    0.016355
# 17      36                   pct_asian    0.016253
# 18     135                some_college    0.016002
# 19      51                unemployment    0.015658
# 20      29           convenience_per1k    0.015641
# 21     137                college_plus    0.015572
# 22      48           pct_nonenglish_hh    0.015522
# 23      34                   pct_black    0.015401
# 24      68           per_capita_income    0.015128
# 25       3          child_lo_store_pct    0.015093
# 26      23              fastfood_per1k    0.014914
# 27       4        seniors_lo_store_pct    0.014908
# 28     138              dia_death_rate    0.014892
# 29       2                lo_store_pct    0.014833
# ..     ...                         ...         ...
# 108    105                          OH    0.000273
# 109     79                          FL    0.000262
# 110     98                          ND    0.000236
# 111     93                          MN    0.000212
# 112    106                          OK    0.000201
# 113     91                          ME    0.000197
# 114     99                          NE    0.000191
# 115     92                          MI    0.000188
# 116    119                          WV    0.000182
# 117    118                          WI    0.000177
# 118    102                          NM    0.000171
# 119     83                          ID    0.000140
# 120     96                          MT    0.000114
# 121    117                          WA    0.000110
# 122     76                          CT    0.000104
# 123    120                          WY    0.000100
# 124     86                          KS    0.000099
# 125     75                          CO    0.000093
# 126     81                          HI    0.000087
# 127     90                          MD    0.000086
# 128    107                          OR    0.000065
# 129    116                          VT    0.000049
# 130     89                          MA    0.000038
# 131     73                          AZ    0.000032
# 132    103                          NV    0.000027
# 133    114                          UT    0.000026
# 134     78                          DE    0.000014
# 135    100                          NH    0.000008
# 136     70                          AK    0.000004
# 137    109                          RI    0.000004
#
# [138 rows x 3 columns]

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
features = feature_importance.feature[:30]
y_pos = np.arange(len(features))
importance = feature_importance.importance[:30]
 
plt.barh(y_pos, importance, alpha=0.5)
plt.yticks(y_pos, features, rotation=90)
plt.xlabel('Importance')
plt.title("Feature Importance, Alzheimer's Mortality Rate")
 
plt.show()

# Example data
features = feature_importance.feature[:30]
y_pos = np.arange(len(features))
importance = feature_importance.importance[:30]
error = np.random.rand(len(features))

plt.barh(y_pos, importance, alpha=0.4)
plt.yticks(y_pos, features)
plt.xlabel('Importance')
plt.title("RFR Feature Importance, Alzheimer's Mortality")

plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt


# Example data
features = feature_importance.feature[:30]
y_pos = np.arange(len(features))
importance = feature_importance.importance[:30]
error = np.random.rand(len(features))

plt.barh(y_pos, importance, alpha=0.4)
plt.yticks(y_pos, features)
plt.xlabel('Importance')
plt.title("RFR Feature Importance, Alzheimer's Mortality")

plt.show()

# %%
Image("/Users/deniseremhof/Downloads/dia_mort_fi.png")

# %%
Image("/Users/deniseremhof/Downloads/dia_fi.png")

# %% [markdown]
# #### What do these feature importances tell us?
#
# The features in the Diabetes/Diabetes mortality rate models show clear similarities--it's easy to deduce feature relationships even with the black box nature of the models. Features that correlate to high Diabetes mortality rate and Adult Diabetes include:
#
# * Poverty/Low Income
# * Food Insecurity/Access
# * Low education
# * Usage of government food aid such as SNAP
# * High overall mortality rate
#
# The features in the Alzheimer's mortality rate model are hard to decipher. They include:
# * college education
# * mortality rate
# * SNAP benefits (like the other models)
# * population density,
# * primary industry in that county (manufacturing)
# * race (white, Native, Asian).
#
# Because the collinearity of these features is tough to tease out on feature importance alone, I used Lasso and a single Decision Tree to dig into feature relationships for Alzheimer's mortality rate.

# %% [markdown]
# ### Teasing out feature interactions w/ a single Decision Tree
#
# The model performed ok, but the feature importances don't make the model's interactions any clearer. Let's try a Decision Tree to see variable coefficients & cancel out noise variables.

# %%
from sklearn.grid_search import GridSearchCV

tree = DecisionTreeRegressor( )

params = {'max_depth':[2,3,4,5,6,None], 
          'max_features':['sqrt','log2'],
          'min_samples_split':[2,4,8,16,32,64,128]
         }

estimator_dtr = GridSearchCV(tree, params, n_jobs=1, cv=5, verbose=2)

# %%
model = estimator_dtr.fit(X_train, y_train)

# %%
## Print best estimator, best parameters, and best score
dtr_best = estimator_dtr.best_estimator_
print "best estimator", dtr_best
print "\n==========\n"
print "best parameters", estimator_dtr.best_params_
print "\n==========\n"
print "best score", estimator_dtr.best_score_
# Out:
# best estimator DecisionTreeRegressor(criterion='mse', max_depth=4, max_features='sqrt',
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=128,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')
#
# ==========
#
# best parameters {'max_features': 'sqrt', 'min_samples_split': 128, 'max_depth': 4}
#
# ==========
#
# best score 0.121387921328

# %%
dot_data = StringIO()  

export_graphviz(dtr_best, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,
                feature_names=X.columns)  

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %%
alz.pop_density.describe()
# Out:
# count     2701.000000
# mean       300.785450
# std       1854.915418
# min          0.800000
# 25%         25.900000
# 50%         56.200000
# 75%        141.100000
# max      69468.400000
# Name: pop_density, dtype: float64

# %% [markdown]
# #### What does the single Decision Tree tell us?
#
# This model has fewer important variables, but we can see from the interactions that the following features have a positive impact on Alzheimer's mortality rates:
#
# * Low population density
# * Low income

# %%
fi = pd.DataFrame({
        'feature':X.columns,
        'importance':dtr_best.feature_importances_
    })

fi.sort_values('importance', ascending=False, inplace=True)
fi.head(11)
# Out:
#                  feature  importance
# 47           pop_density    0.364615
# 37            pct_native    0.162300
# 16            soda_price    0.095803
# 13   household_foodinsec    0.085944
# 41      median_hh_income    0.085306
# 28      superstore_per1k    0.052998
# 67       inactivity_rate    0.037286
# 32      wic_stores_per1k    0.037164
# 66              vets_pct    0.034930
# 39            pct_over65    0.026977
# 137         college_plus    0.016676

# %%
features = feature_importance.feature[:20]
y_pos = np.arange(len(features))
importance = feature_importance.importance[:20]
 
plt.bar(y_pos, importance, alpha=0.5)
plt.xticks(y_pos, features, rotation=90)
plt.ylabel('Importance')
plt.title("Feature Importance, Alzheimer's Mortality Rate")
 
plt.show()

# %% [markdown]
# ### LassoCV
#
# Running Lasso to further clarify the impact of individual variables on the model via coefficients.

# %%
## Train test split 70/30
from sklearn.linear_model import LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.cross_validation import train_test_split

ss = StandardScaler()

# use the "fit_transform" function to normalize the X design matrix
Xn = ss.fit_transform(X)
test = pd.DataFrame(columns = X.columns, data =Xn )
Xn=test

# %%
X_train, X_test, y_train, y_test = train_test_split(Xn, y, test_size=0.3)

## Print shapes of X(s) and y(s)
print X_train.shape, y_train.shape
print X_test.shape, y_test.shape

lassocv = LassoCV(n_alphas=200, verbose=1)
lassocv.fit(X_train, y_train)
# Out:
# (1890, 139) (1890,)
# (811, 139) (811,)
# ............................................................................................................................................................................../Users/deniseremhof/anaconda/envs/dsi/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:466: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations
#   ConvergenceWarning)
# ..........................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.7s finished
# LassoCV(alphas=None, copy_X=True, cv=None, eps=0.001, fit_intercept=True,
#     max_iter=1000, n_alphas=200, n_jobs=1, normalize=False, positive=False,
#     precompute='auto', random_state=None, selection='cyclic', tol=0.0001,
#     verbose=1)

# %%
lassocv.alpha_
# Out:
# 0.11750738308713475

# %%
lassocv.score(X_test, y_test)
# Out:
# 0.37120199485959726

# %%
alz.pop_density.describe()
# Out:
# count     2701.000000
# mean       300.785450
# std       1854.915418
# min          0.800000
# 25%         25.900000
# 50%         56.200000
# 75%        141.100000
# max      69468.400000
# Name: pop_density, dtype: float64

# %%
lasso_coefs = pd.DataFrame({
        'predictor':X_train.columns,
        'coef':lassocv.coef_,
        'abscoef':np.abs(lassocv.coef_)
    })

lasso_coefs.sort_values('abscoef', ascending=False, inplace=True)
lasso_coefs.drop('abscoef', axis=1, inplace=True)
lasso_coefs
# Out:
#          coef                      predictor
# 69   7.569267                 mortality_rate
# 137  2.248509                   college_plus
# 51  -1.808307                   unemployment
# 104 -1.599829                             NY
# 7   -1.512206                snap_per_capita
# 46  -1.306783                 pop_loss_class
# 80   1.208818                             GA
# 67  -1.160667                inactivity_rate
# 110  1.148975                             SC
# 94  -1.046119                             MO
# 101 -1.043605                             NJ
# 47  -1.021928                    pop_density
# 97   0.979728                             NC
# 63   0.950053  retirement_destination_county
# 55  -0.918949              pct_employed_govt
# 72  -0.909993                             AR
# 122  0.902229                metro_250k_1mil
# 52  -0.884594       pct_employed_agriculture
# 43  -0.854533       per_poverty_county_class
# 37  -0.850788                     pct_native
# 33   0.785003                      pct_white
# 134 -0.751695                        hs_only
# 106 -0.726803                             OK
# 113  0.720239                             TX
# 40   0.706913                    pct_under18
# 108 -0.699916                             PA
# 103 -0.669795                             NV
# 128 -0.619362              micro_nonmetroadj
# 18  -0.612273                soda_tax_stores
# 93   0.609572                             MN
# ..        ...                            ...
# 11  -0.000000          active_high_schoolers
# 13  -0.000000            household_foodinsec
# 73   0.000000                             AZ
# 70   0.000000                             AK
# 75   0.000000                             CO
# 22  -0.000000                       food_tax
# 68   0.000000              per_capita_income
# 26   0.000000        per_capita_full_service
# 79  -0.000000                             FL
# 21  -0.000000              chips_tax_vending
# 81  -0.000000                             HI
# 66   0.000000                       vets_pct
# 84  -0.000000                             IL
# 85  -0.000000                             IN
# 20  -0.000000               chips_tax_stores
# 87  -0.000000                             KY
# 88  -0.000000                             LA
# 38   0.000000                     pct_hawaii
# 90  -0.000000                             MD
# 64  -0.000000             hi_natural_amenity
# 92   0.000000                             MI
# 19  -0.000000               soda_tax_vending
# 17  -0.000000                milk_soda_price
# 61   0.000000           low_education_county
# 16   0.000000                     soda_price
# 98   0.000000                             ND
# 99   0.000000                             NE
# 15  -0.000000                     milk_price
# 14  -0.000000                child_foodinsec
# 89  -0.000000                             MA
#
# [139 rows x 2 columns]

# %%
# with interactions:
import patsy

X_formula = '~ (' +' + '.join(X_train.columns)+')**2 -1'
X_train_inter = patsy.dmatrix(X_formula, data=X_train, return_type='dataframe')

print X_train_inter.shape
# Out:
# (1890, 9730)

# %%
from sklearn.linear_model import LassoCV

lassocv = LassoCV(n_alphas=100, verbose=1)
lassocv.fit(X_train_inter, y_train)
# Out:
# ............................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed: 15.8min finished
# LassoCV(alphas=None, copy_X=True, cv=None, eps=0.001, fit_intercept=True,
#     max_iter=1000, n_alphas=100, n_jobs=1, normalize=False, positive=False,
#     precompute='auto', random_state=None, selection='cyclic', tol=0.0001,
#     verbose=1)

# %%
lasso_coefs = pd.DataFrame({
        'predictor':X_train_inter.columns,
        'coef':lassocv.coef_,
        'abscoef':np.abs(lassocv.coef_)
    })

lasso_coefs.sort_values('abscoef', ascending=False, inplace=True)
lasso_coefs.drop('abscoef', axis=1, inplace=True)
lasso_coefs.head(40)
# Out:
#           coef                                          predictor
# 69    4.264072                                     mortality_rate
# 137   1.701552                                       college_plus
# 51   -1.326701                                       unemployment
# 52   -1.124671                           pct_employed_agriculture
# 46   -0.938054                                     pop_loss_class
# 122   0.887301                                    metro_250k_1mil
# 134  -0.832376                                            hs_only
# 50   -0.798476                            pct_hh_65plus_livealone
# 63    0.757211                      retirement_destination_county
# 5039 -0.600075                                median_hh_income:NY
# 1439  0.599238                                adult_obese_rate:NY
# 41    0.567610                                   median_hh_income
# 1975 -0.471550                        household_foodinsec:hs_only
# 2531 -0.470899                                 soda_tax_stores:GA
# 1700 -0.459812                           active_high_schoolers:SC
# 55   -0.457963                                  pct_employed_govt
# 6784  0.443955                            low_education_county:WV
# 5259 -0.443061            per_poverty_county_class:no_high_school
# 1110 -0.417771                          snap_per_capita:pct_black
# 8067  0.400444                    GA:noncore_microadj_lessthan20k
# 6668 -0.392281                               recreation_county:GA
# 6118  0.383969                      pct_employed_manufacturing:NC
# 5252  0.352756      per_poverty_county_class:small_metro_adj_2500
# 2428  0.352081                                 milk_soda_price:NC
# 2664  0.348977                                soda_tax_vending:MO
# 1317  0.348102                             adult_diabetes_rate:SD
# 2718  0.347142                        chips_tax_stores:spec_per1k
# 807   0.333694    seniors_lo_store_pct:noncore_smallmetroadj_2500
# 25    0.331173                               per_capita_fast_food
# 3208  0.326783                full_service_per1k:mining_dependent
# 657   0.325988                              child_lo_store_pct:SD
# 5171 -0.324723  per_poverty_county_class:per_child_poverty_cou...
# 6116 -0.318420                      pct_employed_manufacturing:MS
# 3277  0.307181      full_service_per1k:noncore_smallmetroadj_2500
# 1519 -0.297344                 child_obese_rate:farming_dependent
# 6851 -0.297280                           low_employment_county:SC
# 4647 -0.284899                                      pct_native:OK
# 2432 -0.282465                                 milk_soda_price:NJ
# 3371  0.282170                            per_capita_fast_food:PA
# 5884 -0.280481            pct_hh_65plus_livealone:metro_1mil_plus

# %% [markdown]
# #### Lasso tells us that the following relate to higher Alzheimer's mortality rates:
#
# * High income (especially when in larger metro areas)
# * High obesity (especially when in larger metro areas)
# * High levels of education (some college +)
# * High overall age-adjusted mortality rate
# * County classification as a retirement destination. This measure is particularly interesting because the Alzheimer's mortality rates have been age-adjusted. This means that there's something important about retirement communities OTHER than advanced age of county residence.
# * High fast food consumption
# * Low unemployment

# %% [markdown]
# ### Conclusions & Further Research
#
# The incidence of Adult Diabetes in a given county is highly predictable, while age-adjusted Diabetes & Alzheimer's mortality rates are less so.
#
# While Adult Diabetes and Diabetes mortality share several variables, Alzheimer's mortality predictors differ slightly from them. Any medical relationship between Alzheimer's and Diabetes doesn't manifest itself strongly in the given predictors.
#
# It's possible that the publicly available county-level predictors are insufficient for the purpose of Alzheimer's incidence. Future Alzheimer's research should consider other factors not included in this report. For example, county-level data on blood glucose levels or sugar consumption might provide better links between Diabetes & Alzheimer's.
#
# It's a shame that county-level Alzheimer's rates aren't available, as they'd likely provide more clarity than Alzheimer's rates alone. These Alzheimer's county rates have been imputed by other studies, but the data is unavailable to the public.
